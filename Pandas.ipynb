# %%
import pandas as pd

# %%
iris_df = pd.read_csv("d1.csv")
print(iris_df)
print(type(iris_df))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame=iris_df.copy()
data_frame.head()
data_frame.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
print(data_frame.shape)
print(data_frame.dtypes)
# Out:
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
#data_frame.species
data_frame["species"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
data_frame.isnull()
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data_frame.iloc[0:2,0:3]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4

# %%
data_frame.drop(0, inplace=True)
data_frame.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-20-2775882487.py in <cell line: 0>()
# ----> 1 data_frame.drop(0, inplace=True)
#       2 data_frame.head()
#       3
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
new_df=data_frame.drop(1)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
new_df.index
#new_df.index[0]
# Out:
# RangeIndex(start=2, stop=150, step=1)

# %%
new_df.drop(new_df.index[0], inplace=True)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa

# %%
new_df.petal_width>0.2
# Out:
# 4      False
# 5       True
# 6       True
# 7      False
# 8      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_width, Length: 146, dtype: bool

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    146.000000   146.000000    146.000000   146.000000
# mean       5.871233     3.050000      3.823288     1.226027
# std        0.821098     0.437745      1.743917     0.755125
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.125000     2.800000      1.600000     0.325000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df[new_df.petal_width>0.2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# 16            5.4          3.9           1.3          0.4     Iris-setosa
# 17            5.1          3.5           1.4          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [116 rows x 5 columns]

# %%
new_df[new_df.petal_width>0.2].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    116.000000   116.000000    116.000000   116.000000
# mean       6.105172     2.963793      4.438793     1.496552
# std        0.740369     0.419606      1.402406     0.599410
# min        4.500000     2.000000      1.300000     0.300000
# 25%        5.600000     2.700000      4.000000     1.200000
# 50%        6.100000     3.000000      4.700000     1.500000
# 75%        6.600000     3.200000      5.400000     1.925000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df[new_df.species== 'Iris-virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
print(new_df.head())
print(new_df.iloc[0])  #index
#print(new_df.loc[0])  #labels
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# sepal_length            5.0
# sepal_width             3.6
# petal_length            1.4
# petal_width             0.2
# species         Iris-setosa
# Name: 4, dtype: object

# %%
new_df.loc[0]=[4.5,3.1,1.5,0.3,"setosa"]
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa

# %%
new_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 0             4.5          3.1           1.5          0.3          setosa

# %%
new_df.reset_index(drop=True,inplace=True)
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width  \
# 0        0           5.0          3.6           1.4          0.2
# 1        1           5.4          3.9           1.7          0.4
# 2        2           4.6          3.4           1.4          0.3
# 3        3           5.0          3.4           1.5          0.2
# 4        4           4.4          2.9           1.4          0.2
# ..     ...           ...          ...           ...          ...
# 142    142           6.3          2.5           5.0          1.9
# 143    143           6.5          3.0           5.2          2.0
# 144    144           6.2          3.4           5.4          2.3
# 145    145           5.9          3.0           5.1          1.8
# 146    146           4.5          3.1           1.5          0.3
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146          setosa
#
# [147 rows x 6 columns]

# %%
new_df.drop(columns=["index"], inplace=True)
print(new_df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.0          3.6           1.4          0.2     Iris-setosa
# 1             5.4          3.9           1.7          0.4     Iris-setosa
# 2             4.6          3.4           1.4          0.3     Iris-setosa
# 3             5.0          3.4           1.5          0.2     Iris-setosa
# 4             4.4          2.9           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 142           6.3          2.5           5.0          1.9  Iris-virginica
# 143           6.5          3.0           5.2          2.0  Iris-virginica
# 144           6.2          3.4           5.4          2.3  Iris-virginica
# 145           5.9          3.0           5.1          1.8  Iris-virginica
# 146           4.5          3.1           1.5          0.3          setosa
#
# [147 rows x 5 columns]

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.861905     3.050340      3.807483     1.219728
# std        0.826060     0.436263      1.748467     0.756401
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
del new_df["sepal_width"]
new_df.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-56-3968790934.py in <cell line: 0>()
# ----> 1 del new_df["sepal_width"]
#       2 new_df.describe()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __delitem__(self, key)
#    4504             # there was no match, this call should raise the appropriate
#    4505             # exception:
# -> 4506             loc = self.axes[-1].get_loc(key)
#    4507             self._mgr = self._mgr.idelete(loc)
#    4508
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'sepal_width'

# %%
print(new_df)
# Out:
#      sepal_length  petal_length  petal_width         species
# 0             5.0           1.4          0.2     Iris-setosa
# 1             5.4           1.7          0.4     Iris-setosa
# 2             4.6           1.4          0.3     Iris-setosa
# 3             5.0           1.5          0.2     Iris-setosa
# 4             4.4           1.4          0.2     Iris-setosa
# ..            ...           ...          ...             ...
# 142           6.3           5.0          1.9  Iris-virginica
# 143           6.5           5.2          2.0  Iris-virginica
# 144           6.2           5.4          2.3  Iris-virginica
# 145           5.9           5.1          1.8  Iris-virginica
# 146           4.5           1.5          0.3          setosa
#
# [147 rows x 4 columns]

# %%
new_df["color"]="white"
new_df.head()
# Out:
#    sepal_length  petal_length  petal_width      species  color
# 0           5.0           1.4          0.2  Iris-setosa  white
# 1           5.4           1.7          0.4  Iris-setosa  white
# 2           4.6           1.4          0.3  Iris-setosa  white
# 3           5.0           1.5          0.2  Iris-setosa  white
# 4           4.4           1.4          0.2  Iris-setosa  white

# %%
import numpy as np
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa

# %%
data_frame.iloc[2:3,2:4]=np.nan
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           NaN          NaN  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa

# %%
data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    148.000000   148.000000
# mean       5.848322     3.051007      3.789865     1.212162
# std        0.828594     0.433499      1.755564     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame.dropna(inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
data_frame.reset_index(drop=True,inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           5.0          3.6           1.4          0.2  Iris-setosa
# 3           5.4          3.9           1.7          0.4  Iris-setosa
# 4           4.6          3.4           1.4          0.3  Iris-setosa

# %%
data_frame.iloc[2:3,2:4]=np.nan
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           5.0          3.6           NaN          NaN  Iris-setosa
# 3           5.4          3.9           1.7          0.4  Iris-setosa
# 4           4.6          3.4           1.4          0.3  Iris-setosa

# %%
#find mean/median/mode or most occuring value


data_frame.petal_length.fillna(data_frame.petal_length.mean(),inplace=True)
data_frame.head()
# Out:
# /tmp/ipython-input-71-3657118981.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_frame.petal_length.fillna(data_frame.petal_length.mean(),inplace=True)
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0      1.400000          0.2  Iris-setosa
# 1           4.7          3.2      1.300000          0.2  Iris-setosa
# 2           5.0          3.6      3.806122          NaN  Iris-setosa
# 3           5.4          3.9      1.700000          0.4  Iris-setosa
# 4           4.6          3.4      1.400000          0.3  Iris-setosa

# %%
temp=data_frame[data_frame.species=="Iris-setosa"]
data_frame.petal_width.fillna(temp.petal_width.mean(),inplace=True)
data_frame.head()
# Out:
# /tmp/ipython-input-72-2707780759.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_frame.petal_width.fillna(temp.petal_width.mean(),inplace=True)
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0      1.400000     0.200000  Iris-setosa
# 1           4.7          3.2      1.300000     0.200000  Iris-setosa
# 2           5.0          3.6      3.806122     0.246809  Iris-setosa
# 3           5.4          3.9      1.700000     0.400000  Iris-setosa
# 4           4.6          3.4      1.400000     0.300000  Iris-setosa
